# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_excel("data/Численность_постоянного_населения_в_среднем_за_год.xlsx")
raw_data
# Out:
#                         Unnamed: 0    Unnamed: 1  \
# 0                              NaN           NaN
# 1                    все население  w2:p_mest:11
# 2             Российская Федерация           643
# 3    Центральный федеральный округ           030
# 4             Белгородская область   14000000000
# ..                             ...           ...
# 97             Магаданская область   44000000000
# 98             Сахалинская область   64000000000
# 99    Еврейская автономная область   99000000000
# 100     Чукотский автономный округ   77000000000
# 101     Крымский федеральный округ           039
#
#     23110000100040200001 Численность постоянного населения в среднем за год  \
# 0                                              2014 г.
# 1                                                  NaN
# 2                                            146090613
# 3                                             38885676
# 4                                              1546022
# ...

# %%
raw_data.columns = raw_data.loc[0, :]
raw_data.columns
# Out:
# Index([      nan,       nan, '2014 г.', '2015 г.', '2016 г.', '2017 г.',
#        '2018 г.', '2019 г.', '2020 г.'],
#       dtype='object', name=0)

# %%
data_1 = raw_data.drop(1)
data_1
# Out:
# 0                              NaN          NaN    2014 г.    2015 г.  \
# 0                              NaN          NaN    2014 г.    2015 г.
# 2             Российская Федерация          643  146090613  146405999
# 3    Центральный федеральный округ          030   38885676   39027899
# 4             Белгородская область  14000000000    1546022    1549037
# 5                 Брянская область  15000000000    1237769    1229340
# ..                             ...          ...        ...        ...
# 97             Магаданская область  44000000000     149191     147208
# 98             Сахалинская область  64000000000     489708     487842
# 99    Еврейская автономная область  99000000000     169372     167243
# 100     Чукотский автономный округ  77000000000      50548      50349
# 101     Крымский федеральный округ          039    2270947    2309129
#
# 0      2016 г.    2017 г.    2018 г.    2019 г.    2020 г.
# 0      2016 г.    2017 г.    2018 г.    2019 г.    2020 г.
# ...

# %%
data_1 = data_1.drop(0)
data_1
# Out:
# 0                              NaN          NaN    2014 г.    2015 г.  \
# 2             Российская Федерация          643  146090613  146405999
# 3    Центральный федеральный округ          030   38885676   39027899
# 4             Белгородская область  14000000000    1546022    1549037
# 5                 Брянская область  15000000000    1237769    1229340
# 6             Владимирская область  17000000000    1409467    1401390
# ..                             ...          ...        ...        ...
# 97             Магаданская область  44000000000     149191     147208
# 98             Сахалинская область  64000000000     489708     487842
# 99    Еврейская автономная область  99000000000     169372     167243
# 100     Чукотский автономный округ  77000000000      50548      50349
# 101     Крымский федеральный округ          039    2270947    2309129
#
# 0      2016 г.    2017 г.    2018 г.    2019 г.    2020 г.
# 2    146674541  146842401  146830575  146764655  146459803
# ...

# %%
col_arr = np.array(data_1.columns)
col_arr
# Out:
# array([nan, nan, '2014 г.', '2015 г.', '2016 г.', '2017 г.', '2018 г.',
#        '2019 г.', '2020 г.'], dtype=object)

# %%
data_1.columns = col_arr.astype("str")
data_1.columns
# Out:
# Index(['nan', 'nan', '2014 г.', '2015 г.', '2016 г.', '2017 г.', '2018 г.',
#        '2019 г.', '2020 г.'],
#       dtype='object')

# %%
data_2 = data_1.T
data_2
# Out:
#                           2                              3    \
# nan      Российская Федерация  Центральный федеральный округ
# nan                       643                            030
# 2014 г.             146090613                       38885676
# 2015 г.             146405999                       39027899
# 2016 г.             146674541                       39156950
# 2017 г.             146842401                       39260498
# 2018 г.             146830575                       39344736
# 2019 г.             146764655                       39405807
# 2020 г.             146459803                       39342258
#
#                           4                 5                     6    \
# nan      Белгородская область  Брянская область  Владимирская область
# nan               14000000000       15000000000           17000000000
# 2014 г.               1546022           1237769               1409467
# 2015 г.               1549037           1229340               1401390
# ...

# %%
data_2.iloc[0, :]
# Out:
# 2               Российская Федерация
# 3      Центральный федеральный округ
# 4               Белгородская область
# 5                   Брянская область
# 6               Владимирская область
#                    ...
# 97               Магаданская область
# 98               Сахалинская область
# 99      Еврейская автономная область
# 100       Чукотский автономный округ
# 101       Крымский федеральный округ
# Name: nan, Length: 100, dtype: object

# %%
data_2.columns = data_2.iloc[0, :]
data_2 = data_2.drop("nan")
data_2
# Out:
# nan     Российская Федерация Центральный федеральный округ  \
# 2014 г.            146090613                      38885676
# 2015 г.            146405999                      39027899
# 2016 г.            146674541                      39156950
# 2017 г.            146842401                      39260498
# 2018 г.            146830575                      39344736
# 2019 г.            146764655                      39405807
# 2020 г.            146459803                      39342258
#
# nan     Белгородская область Брянская область Владимирская область  \
# 2014 г.              1546022          1237769              1409467
# 2015 г.              1549037          1229340              1401390
# 2016 г.              1551500          1223135              1393383
# 2017 г.              1551370          1215756              1383968
# 2018 г.              1548647          1205584              1372071
# 2019 г.              1548284          1196339              1362110
# ...

# %%
data_2.select_dtypes(include="object")
# Out:
# nan     Российская Федерация Центральный федеральный округ  \
# 2014 г.            146090613                      38885676
# 2015 г.            146405999                      39027899
# 2016 г.            146674541                      39156950
# 2017 г.            146842401                      39260498
# 2018 г.            146830575                      39344736
# 2019 г.            146764655                      39405807
# 2020 г.            146459803                      39342258
#
# nan     Белгородская область Брянская область Владимирская область  \
# 2014 г.              1546022          1237769              1409467
# 2015 г.              1549037          1229340              1401390
# 2016 г.              1551500          1223135              1393383
# 2017 г.              1551370          1215756              1383968
# 2018 г.              1548647          1205584              1372071
# 2019 г.              1548284          1196339              1362110
# ...

# %%
data_2.select_dtypes(include="object").columns
# Out:
# Index(['Российская Федерация', 'Центральный федеральный округ',
#        'Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'Липецкая область',
#        'Московская область', 'Орловская область', 'Рязанская область',
#        'Смоленская область', 'Тамбовская область', 'Тверская область',
#        'Тульская область', 'Ярославская область',
#        'Город Москва столица Российской Федерации город федерального значения',
#        'Северо-Западный федеральный округ', 'Республика Карелия',
#        'Республика Коми', 'Архангельская область',
#        'Ненецкий автономный округ (Архангельская область)',
#        'Архангельская область (кроме Ненецкого автономного округа)',
#        'Вологодская область', 'Калининградская область',
#        'Ленинградская область', 'Мурманская область', 'Новгородская область',
#        'Псковская область',
# ...

# %%
data_2["Крымский федеральный округ"].unique()
# Out:
# array([2270947, 2309129, nan], dtype=object)

# %%
data_3 = data_2.replace("nan", "год")
data_3["Крымский федеральный округ"].unique()
# Out:
# array([2270947, 2309129, nan], dtype=object)
